# %%
import numpy as np
import pandas as pd

# %%
# import libraries

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, confusion_matrix

import seaborn as sns

# %%
# Read the data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

# %%
# Preview train data

train.head()
# Out:
#    id          brand                    model  release_year milage fuel_type  \
# 0   0           Jeep       Gladiator Overland          2019   4.1k  Gasoline
# 1   1       Chrysler                300M Base          2004  45.0k  Gasoline
# 2   2        Hyundai  Genesis Coupe 3.8 Track          2010  11.5k  Gasoline
# 3   3           Ford             F-150 Lariat          2013  28.0k  Gasoline
# 4   4  Mercedes-Benz  SL-Class SL550 Roadster          2010  21.3k  Gasoline
#
#                                           engine  \
# 0  285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 1  250.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 2  306.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 3  400.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4   382.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
#
#                         transmission exterior_color interior_color  \
# 0             Automatic Transmission            Red              –
# 1             Automatic Transmission         Silver          Black
# 2  Transmission with Dual Shift Mode         Silver          Black
# 3     6-Speed Automatic Transmission           Gray          Black
# 4     7-Speed Automatic Transmission          Black          Black
#
#                accident_report clean_title  price
# 0                None reported         Yes  47500
# 1                None reported         Yes   8250
# 2  1 or more accident reported         Yes  12000
# 3  1 or more accident reported         Yes  13000
# 4  1 or more accident reported         Yes  15400

# %%
# Preview test data

test.head()
# Out:
#    id          brand                        model  release_year  milage  \
# 0   0  Mercedes-Benz     AMG C 43 AMG C 43 4MATIC          2019   36.0k
# 1   1  Mercedes-Benz                EQS 450+ Base          2017   66.0k
# 2   2          Tesla      Model X Long Range Plus          2019   55.0k
# 3   3           Ford  Bronco Outer Banks Advanced          2022   16.5k
# 4   4            GMC     Sierra 1500 SLE Crew Cab          2006  215.0k
#
#   fuel_type                                         engine  \
# 0  Gasoline  385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 1  Gasoline  329.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 2  Gasoline    425.0HP Electric Motor Electric Fuel System
# 3  Gasoline  315.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 4  Gasoline   295.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
#
#                         transmission exterior_color interior_color  \
# 0     8-Speed Automatic Transmission         Silver          Black
# 1  Transmission with Dual Shift Mode           Gray          Beige
# 2     2-Speed Automatic Transmission           Blue          Black
# 3    10-Speed Automatic Transmission          White          Brown
# 4             Automatic Transmission          Black           Gray
#
#                accident_report clean_title
# 0                None reported         Yes
# 1                None reported         Yes
# 2                None reported         Yes
# 3  1 or more accident reported         Yes
# 4  1 or more accident reported         Yes

# %%
# Process the data

X_train = train[['id', 'release_year']]
y_train = train['price']

# %%
# Train a model

model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions

final_predictions = model.predict(test[['id', 'release_year']])

submission['price'] = final_predictions

# %%
# Save the submission file

submission.to_csv('submission.csv', index=False)
